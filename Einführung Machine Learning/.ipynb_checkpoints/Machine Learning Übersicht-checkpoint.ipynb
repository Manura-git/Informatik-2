# %% [markdown]
# ### Übersicht

# %% [markdown]
# ### Ressources
# #### Einführung
# [Vorlesungsskript pandas, statistik, altair](https://pds.mylab.th-luebeck.de/)
# [MLU Linear Regression](https://mlu-explain.github.io/linear-regression/)
# [TensorFlow playground](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.18974&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)
# [3b1b Neural Networks](https://www.3blue1brown.com/?topic=neural-networks)
# [Video über neuronale Netzwertke und Bilderkennung](https://www.youtube.com/watch?v=FmpDIaiMIeA)
#
# #### Entscheidungsbäume
# [Skript Entscheidungsbäume](https://lernraum.th-luebeck.de/pluginfile.php/736031/mod_resource/content/0/Skript%20Entscheidungsba%CC%88ume.pdf)
# [MLU Entscheidungsbäume](https://mlu-explain.github.io/decision-tree/)
# [Artikel Entscheidungsbäume](https://link.springer.com/article/10.1007/s00287-021-01398-0)

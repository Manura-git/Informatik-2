# %% [markdown]
# ### Übersicht

# %% [markdown]
# #### Ressources
# [Pandas Dokumentation](https://pandas.pydata.org/docs/)
# [Pandas API Reference](https://pandas.pydata.org/docs/reference/index.html)
# [McKinney Buch](https://wesmckinney.com/book/)
# [Github von Herr Knuth über pandas,numpy, und altair](https://github.com/tknuth/python-data-science)
# [Github von Herr Knuth über Python Grundlagen](https://github.com/tknuth/python-grundlagen)
